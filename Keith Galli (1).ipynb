# %% [markdown]
# pwd

# %%
cd /Users/HP/Desktop/Data Science/Project
# Out:
# C:\Users\HP\Desktop\Data Science\Project

# %%
df.iloc[:5,:6]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack
# 0  1              Bulbasaur  Grass  Poison  45      49
# 1  2                Ivysaur  Grass  Poison  60      62
# 2  3               Venusaur  Grass  Poison  80      82
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100
# 4  4             Charmander   Fire     NaN  39      52

# %%
for index,row in df.iterrows():
    print(index,row)
# Out:
# 0 #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object
# 1 #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object
# 2 #                    3
# Name          Venusaur
# Type 1           Grass
# Type 2          Poison
# HP                  80
# Attack              82
# Defense             83
# Sp. Atk            100
# Sp. Def            100
# Speed               80
# Generation           1
# Legendary        False
# Name: 2, dtype: object
# ...

# %%
df[df['Type 1']=="Fire"]
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
pwd
# Out:
# 'C:\\Users\\HP'

# %%
cd /Users/HP/Desktop/Data Science/Project
# Out:
# C:\Users\HP\Desktop\Data Science\Project

# %%
import pandas as pd
df=pd.read_csv("pokemon_data.csv")
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.sort_values('Name')
## NAME IN Ascending Order
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values('Name',ascending=False)
## In Descending Order
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
##  df.sort_values(['Type 1','HP'])
## i.e. Both Type 1 and and HP in alpabetic and ascending order
df.sort_values (['Type 1','HP'],ascending=True)
# Out:
#        #       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292   Shedinja    Bug   Ghost    1      90       45       30       30
# 230  213    Shuckle    Bug    Rock   20      10      230       10      230
# 462  415     Combee    Bug  Flying   30      30       42       30       42
# 603  543   Venipede    Bug  Poison   30      45       59       30       39
# 314  290    Nincada    Bug  Ground   31      45       90       30       30
# ..   ...        ...    ...     ...  ...     ...      ...      ...      ...
# 142  131     Lapras  Water     Ice  130      85       80       85       95
# 145  134   Vaporeon  Water     NaN  130      65       60      110       95
# 350  320    Wailmer  Water     NaN  130      70       35       70       35
# 655  594  Alomomola  Water     NaN  165      75       80       40       45
# 351  321    Wailord  Water     NaN  170      90       45       90       45
#
#      Speed  Generation  Legendary
# ...

# %%
df.sort_values (['Type 1','HP'],ascending=[1,0])
#i.e. Type 1 in alphabetic and HP in descending Order
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
## MAKING A NEW COLUMNN TOTAL SO THAT WE ADD up all features and find the best pokemon
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
### IF you want to remove a column Total
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']
df.head()
##Start From Here
df = df.drop(columns=['Total'])
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# Another Way of creating Total Column
# iloc  (:) - All Rows
#iloc    (4:9) - Cloumn 4 to 9 using index  
#(n,n-1) therefore we have to put(4,10)
# sum = iloc (axis=1)means adding horizontally
#axis=0 if we want to add vertically

df['Total'] = df.iloc[:,4:10].sum(axis=1)
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
# Interchanging columns
df['Total'] = df.iloc[:,4:10].sum(axis=1)
df.head()

## Starts from Here
cols = list(df.columns)
df = df[cols[0:4]+[cols[-1]]+cols[4:12]]
df.head()

#Saving this New file into your computer Folder
df.to_csv('modified.csv')
##The file reaches its cd location 

# If you want to download the file without index
# df.to_csv('modified.csv',index=False)

# If you Want to save an excel file
# df.to_excel('modified.xlsx',index=False)

# %%
# Interchanging columns
df['Total'] = df.iloc[:,4:10].sum(axis=1)
df.head()

## Starts from Here
cols = list(df.columns)
df = df[cols[0:4]+[cols[-1]]+cols[4:12]]
df.head()
# Out:
#    #                   Name Type 1  Type 2  Sp. Def  Speed  Generation  \
# 0  1              Bulbasaur  Grass  Poison       65     45           1
# 1  2                Ivysaur  Grass  Poison       80     60           1
# 2  3               Venusaur  Grass  Poison      100     80           1
# 3  3  VenusaurMega Venusaur  Grass  Poison      120     80           1
# 4  4             Charmander   Fire     NaN       50     65           1
#
#    Legendary   Total  HP  Attack  Defense  Sp. Atk
# 0      False  1083.0  45      49       49       65
# 1      False  1384.0  60      62       63       80
# 2      False  1804.0  80      82       83      100
# 3      False  2160.0  80     100      123      122
# 4      False  1039.0  39      52       43       60

# %%
## FILTERING OF DATA
df[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison')]

#df.loc is used to filter for text values
#So the code is
#df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison')]
# Out:
#        #                   Name Type 1  Type 2  Sp. Def  Speed  Generation  \
# 0      1              Bulbasaur  Grass  Poison       65     45           1
# 1      2                Ivysaur  Grass  Poison       80     60           1
# 2      3               Venusaur  Grass  Poison      100     80           1
# 3      3  VenusaurMega Venusaur  Grass  Poison      120     80           1
# 48    43                 Oddish  Grass  Poison       65     30           1
# 49    44                  Gloom  Grass  Poison       75     40           1
# 50    45              Vileplume  Grass  Poison       90     50           1
# 75    69             Bellsprout  Grass  Poison       30     40           1
# 76    70             Weepinbell  Grass  Poison       45     55           1
# 77    71             Victreebel  Grass  Poison       70     70           1
# 344  315                Roselia  Grass  Poison       80     65           3
# ...

# %%
# OR FUNCTION IS ( | )
# df[(df['Type 1'] == 'Grass') | (df['Type 2'] == 'Poison')]

# %%
df[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]

# If i want to make it a new df
new_df = df[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]

# and send it to my folder
#  new_df.to_csv('filtered.csv')

# %%
df[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]

new_df = df[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]

# changing In the new df with no index column

new_df = new_df.reset_index(drop=True)


new_df.head()
# Out:
#      #                   Name Type 1  Type 2  Sp. Def  Speed  Generation  \
# 0    3               Venusaur  Grass  Poison      100     80           1
# 1    3  VenusaurMega Venusaur  Grass  Poison      120     80           1
# 2   45              Vileplume  Grass  Poison       90     50           1
# 3   71             Victreebel  Grass  Poison       70     70           1
# 4  591              Amoonguss  Grass  Poison       80     30           5
#
#    Legendary   Total   HP  Attack  Defense  Sp. Atk
# 0      False  1804.0   80      82       83      100
# 1      False  2160.0   80     100      123      122
# 2      False  1727.0   75      80       85      110
# 3      False  1767.0   80     105       65      100
# 4      False  1760.0  114      85       70       85

# %%
# Under The name column We want to FILTER OUT NAMES WITH MEGA
df.loc[df['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1    Type 2  Sp. Def  Speed  \
# 3      3      VenusaurMega Venusaur     Grass    Poison      120     80
# 7      6  CharizardMega Charizard X      Fire    Dragon       85    100
# 8      6  CharizardMega Charizard Y      Fire    Flying      115    100
# 12     9    BlastoiseMega Blastoise     Water       NaN      115     78
# 19    15      BeedrillMega Beedrill       Bug    Poison       80    145
# 23    18        PidgeotMega Pidgeot    Normal    Flying       80    121
# 71    65      AlakazamMega Alakazam   Psychic       NaN       95    150
# 87    80        SlowbroMega Slowbro     Water   Psychic       80     30
# 102   94          GengarMega Gengar     Ghost    Poison       95    130
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN      100    100
# 137  127          PinsirMega Pinsir       Bug    Flying       90    105
# 141  130      GyaradosMega Gyarados     Water      Dark      130     81
# ...

# %%
# Remove Names cotaining Mega ~
df.loc[~df['Name'].str.contains('Mega')]
# Out:
#        #                 Name   Type 1  Type 2  Sp. Def  Speed  Generation  \
# 0      1            Bulbasaur    Grass  Poison       65     45           1
# 1      2              Ivysaur    Grass  Poison       80     60           1
# 2      3             Venusaur    Grass  Poison      100     80           1
# 4      4           Charmander     Fire     NaN       50     65           1
# 5      5           Charmeleon     Fire     NaN       65     80           1
# ..   ...                  ...      ...     ...      ...    ...         ...
# 794  718     Zygarde50% Forme   Dragon  Ground       95     95           6
# 795  719              Diancie     Rock   Fairy      150     50           6
# 797  720  HoopaHoopa Confined  Psychic   Ghost      130     70           6
# 798  720   HoopaHoopa Unbound  Psychic    Dark      130     80           6
# 799  721            Volcanion     Fire   Water       90     70           6
#
#      Legendary   Total   HP  Attack  Defense  Sp. Atk
# ...

# %%
#Filtering by importing regular expressions and Finding Out Type 1= Fire Or Grass

import re
df.loc[df['Type 1'].str.contains('Fire|Grass',regex=True)]
# Out:
#        #                   Name Type 1  Type 2  Sp. Def  Speed  Generation  \
# 0      1              Bulbasaur  Grass  Poison       65     45           1
# 1      2                Ivysaur  Grass  Poison       80     60           1
# 2      3               Venusaur  Grass  Poison      100     80           1
# 3      3  VenusaurMega Venusaur  Grass  Poison      120     80           1
# 4      4             Charmander   Fire     NaN       50     65           1
# ..   ...                    ...    ...     ...      ...    ...         ...
# 735  667                 Litleo   Fire  Normal       54     72           6
# 736  668                 Pyroar   Fire  Normal       66    106           6
# 740  672                 Skiddo  Grass     NaN       57     52           6
# 741  673                 Gogoat  Grass     NaN       81     68           6
# 799  721              Volcanion   Fire   Water       90     70           6
#
#      Legendary   Total   HP  Attack  Defense  Sp. Atk
# ...

# %%
# If we want to Filter Names starting with Pi , code means Nmae should start with Pi and the next letter be whatever from [a-z]
# * meant any number of characters
# ^ Means The Name starts with Pi, Without it I was Geting Names like # Kumar Picka Ram
df.loc[df['Name'].str.contains('^Pi[a-z]*',regex=True)]
# Out:
#        #                     Name    Type 1    Type 2  Sp. Def  Speed  \
# 20    16                   Pidgey    Normal    Flying       35     56
# 21    17                Pidgeotto    Normal    Flying       50     71
# 22    18                  Pidgeot    Normal    Flying       70    101
# 23    18      PidgeotMega Pidgeot    Normal    Flying       80    121
# 30    25                  Pikachu  Electric       NaN       50     90
# 136  127                   Pinsir       Bug       NaN       70     85
# 137  127        PinsirMega Pinsir       Bug    Flying       90    105
# 186  172                    Pichu  Electric       NaN       35     60
# 219  204                   Pineco       Bug       NaN       35     15
# 239  221                Piloswine       Ice    Ground       60     50
# 438  393                   Piplup     Water       NaN       56     40
# 558  499                  Pignite      Fire  Fighting       55     55
# ...

# %%
#Conditional Changes
# If I want to change 'Fire' in Type 1 as 'Flamer'
df.loc[df['Type 1'] == 'Fire', 'Type 1'] = 'Flamer'
df
# Out:
#        #                   Name   Type 1  Type 2  Sp. Def  Speed  Generation  \
# 0      1              Bulbasaur    Grass  Poison       65     45           1
# 1      2                Ivysaur    Grass  Poison       80     60           1
# 2      3               Venusaur    Grass  Poison      100     80           1
# 3      3  VenusaurMega Venusaur    Grass  Poison      120     80           1
# 4      4             Charmander   Flamer     NaN       50     65           1
# ..   ...                    ...      ...     ...      ...    ...         ...
# 795  719                Diancie     Rock   Fairy      150     50           6
# 796  719    DiancieMega Diancie     Rock   Fairy      110    110           6
# 797  720    HoopaHoopa Confined  Psychic   Ghost      130     70           6
# 798  720     HoopaHoopa Unbound  Psychic    Dark      130     80           6
# 799  721              Volcanion   Flamer   Water       90     70           6
#
# ...

# %%
#Now Change it back
# df.loc[df['Type 1'] == 'Flamer', 'Type 1'] = 'Fire'
# df

# %%
cd /Users/HP/Desktop/Data Science/Project
# Out:
# C:\Users\HP\Desktop\Data Science\Project

# %%
import pandas as pd
df=pd.read_csv("pokemon_data.csv")
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
#Conditional Changes continued
# All Fire To be made Legendary
df.loc[df['Type 1'] == 'Fire', 'Legendary'] = True

df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df = pd.read_csv('modified.csv')

# If (Total >500) then Change multiple conditions
df.loc[df['Total'] > 500, ['Generation','Legendary']] = 'Test Value'
df
# For multiple values
#df.loc[df['Total'] > 500, ['Generation','Legendary']] = ['Test 1','Test 2']
# Out:
#      Unnamed: 0    #                   Name   Type 1  Type 2  Speed  \
# 0             0    1              Bulbasaur    Grass  Poison     45
# 1             1    2                Ivysaur    Grass  Poison     60
# 2             2    3               Venusaur    Grass  Poison     80
# 3             3    3  VenusaurMega Venusaur    Grass  Poison     80
# 4             4    4             Charmander     Fire     NaN     65
# ..          ...  ...                    ...      ...     ...    ...
# 795         795  719                Diancie     Rock   Fairy     50
# 796         796  719    DiancieMega Diancie     Rock   Fairy    110
# 797         797  720    HoopaHoopa Confined  Psychic   Ghost     70
# 798         798  720     HoopaHoopa Unbound  Psychic    Dark     80
# 799         799  721              Volcanion     Fire   Water     70
#
#      Generation   Legendary   Total  HP  Attack  Defense  Sp. Atk  Sp. Def
# 0    Test Value  Test Value   943.0  45      49       49       65       65
# ...

# %%
#Aggregate Statistics
df = pd.read_csv("modified.csv")
 # Group by Function i.e Categorising data by their Means on one variable i.e TYPE 1
df.groupby(['Type 1']).mean()    

# Doing the same by sorting on the basis of Defense ( Top Defender) so Descending Order
# Out:
#           Unnamed: 0           #       Speed  Generation  Legendary  \
# Type 1
# Bug       368.072464  334.492754   61.681159    3.217391   0.000000
# Dark      507.387097  461.354839   76.161290    4.032258   0.064516
# Dragon    521.843750  474.375000   83.031250    3.875000   0.375000
# Electric  400.590909  363.500000   84.500000    3.272727   0.090909
# Fairy     494.529412  449.529412   48.588235    4.117647   0.058824
# Fighting  400.444444  363.851852   66.074074    3.370370   0.000000
# Fire      360.942308  327.403846   74.442308    3.211538   0.096154
# Flying    746.500000  677.750000  102.500000    5.500000   0.500000
# Ghost     536.281250  486.500000   64.343750    4.187500   0.062500
# Grass     380.414286  344.871429   61.928571    3.357143   0.042857
# Ground    392.312500  356.281250   63.906250    3.156250   0.125000
# Ice       465.666667  423.541667   63.458333    3.541667   0.083333
# Normal    351.581633  319.173469   71.551020    3.051020   0.020408
# ...

# %%
df = pd.read_csv("modified.csv")
# Doing the same by sorting on the basis of Defense ( Top Defender) so Descending Order
df.groupby(['Type 1']).mean().sort_values('Defense',ascending=False)    
# The steel and rock Pokemons have Highhest Defense
# Same we can do with Attack
# Out:
#           Unnamed: 0           #       Speed  Generation  Legendary  \
# Type 1
# Steel     486.296296  442.851852   55.259259    3.851852   0.148148
# Rock      431.840909  392.727273   55.909091    3.454545   0.090909
# Dragon    521.843750  474.375000   83.031250    3.875000   0.375000
# Ground    392.312500  356.281250   63.906250    3.156250   0.125000
# Ghost     536.281250  486.500000   64.343750    4.187500   0.062500
# Water     333.312500  303.089286   65.964286    2.857143   0.035714
# Ice       465.666667  423.541667   63.458333    3.541667   0.083333
# Grass     380.414286  344.871429   61.928571    3.357143   0.042857
# Bug       368.072464  334.492754   61.681159    3.217391   0.000000
# Dark      507.387097  461.354839   76.161290    4.032258   0.064516
# Poison    278.285714  251.785714   63.571429    2.535714   0.000000
# Fire      360.942308  327.403846   74.442308    3.211538   0.096154
# Psychic   420.105263  380.807018   81.491228    3.385965   0.245614
# ...

# %%
# df.groupby(['Type 1']).count()
# To Find out the number of Steel , Stone ... pokemons present
#To Sum all values
# df.groupby(['Type 1']).sum()

# %%
df = pd.read_csv('modified.csv')
# Creating A count column =1
df['count'] = 1
#Check Above the same command to find the number of count
df.groupby(['Type 1']).count()
#command to get an output no.15
df.groupby(['Type 1']).count()['count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %%
df = pd.read_csv('modified.csv')
df['count'] = 1
df.groupby(['Type 1','Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %%
# Working  with large amout of data # Chunk in rows of 5
for df in pd.read_csv('modified.csv', chunksize=5):
    print("CHUNK DF")
    print(df)
# Out:
# CHUNK DF
#    Unnamed: 0  #                   Name Type 1  Type 2  Speed  Generation  \
# 0           0  1              Bulbasaur  Grass  Poison     45           1
# 1           1  2                Ivysaur  Grass  Poison     60           1
# 2           2  3               Venusaur  Grass  Poison     80           1
# 3           3  3  VenusaurMega Venusaur  Grass  Poison     80           1
# 4           4  4             Charmander   Fire     NaN     65           1
#
#    Legendary   Total  HP  Attack  Defense  Sp. Atk  Sp. Def
# 0      False   943.0  45      49       49       65       65
# 1      False  1201.0  60      62       63       80       80
# 2      False  1561.0  80      82       83      100      100
# 3      False  1899.0  80     100      123      122      120
# 4      False   882.0  39      52       43       60       50
# CHUNK DF
#    Unnamed: 0  #                       Name Type 1  Type 2  Speed  Generation  \
# ...
